# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
data = pd.read_csv('C:/Users/dhruv/Documents/School/Capstone/rig count by state.csv')
data
# Out:
#            DATE  Alabama Land  Alabama Offshore  Alaska Land  Alaska Offshore  \
# 0      1/7/2000             2                 2            3                1
# 1     1/14/2000             2                 1            6                1
# 2     1/21/2000             1                 1            5                1
# 3     1/28/2000             1                 1            4                1
# 4      2/4/2000             0                 1            4                0
# ...         ...           ...               ...          ...              ...
# 1201  1/13/2023             0                 0            9                0
# 1202  1/20/2023             0                 0            8                0
# 1203  1/27/2023             0                 0            8                0
# 1204   2/3/2023             0                 0            7                0
# 1205  2/10/2023             0                 0            7                0
#
# ...

# %%
data['DATE'] = pd.to_datetime(data['DATE'])
data
# Out:
#            DATE  Alabama Land  Alabama Offshore  Alaska Land  Alaska Offshore  \
# 0    2000-01-07             2                 2            3                1
# 1    2000-01-14             2                 1            6                1
# 2    2000-01-21             1                 1            5                1
# 3    2000-01-28             1                 1            4                1
# 4    2000-02-04             0                 1            4                0
# ...         ...           ...               ...          ...              ...
# 1201 2023-01-13             0                 0            9                0
# 1202 2023-01-20             0                 0            8                0
# 1203 2023-01-27             0                 0            8                0
# 1204 2023-02-03             0                 0            7                0
# 1205 2023-02-10             0                 0            7                0
#
# ...

# %%
plt.plot(data['DATE'], data['Texas Land'], linewidth=2, color='#ed40b1', label="Texas")
plt.plot(data['DATE'], data["N. Mexico Land"], linewidth=2, color="#1a911e", label="New Mexico")
plt.plot(data['DATE'], data['Louisiana Land'], linewidth=2, color="#cc253b", label="Louisiana")
plt.plot(data['DATE'], data['Penn Land'], linewidth=2, color="#2e35bf", label="Pennsylvania")
plt.plot(data['DATE'], data['N. Dakota Land'], linewidth=2, color="#d18213", label="North Dakota")
plt.xlabel("Time")
plt.ylabel("Rig Count on Land")
plt.title("Rig Counts in Five States")
plt.legend()
plt.show()
